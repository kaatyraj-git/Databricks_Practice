# %% [markdown]
# ![](/Volumes/datamasterlearning/bronze/images/object-model.png)

# %% [markdown]
# https://docs.databricks.com/aws/en/database-objects

# %%
# %sql
use catalog datamasterlearning

# %%
# %sql
create schema if not exists bronze;

# %%
# %sql
create table if not exists datamasterlearning.bronze.test(id int, name string, age int);

insert into datamasterlearning.bronze.test (id, name, age) values (1, 'Naval', 33), (2, 'Raj', 39);

# %%
# %sql
select * from datamasterlearning.bronze.test
