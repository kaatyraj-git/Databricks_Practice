# %% [markdown]
# This is my first notebook in DBX practice course.
# This is the edit to it.

# %% [markdown]
# Creating a spark dataframe

# %%
data=[(1,'Naval'),(2,'Raj')]
schema = "id int, name string"

# %%
df=spark.createDataFrame(data,schema)

# %%
display(df)
